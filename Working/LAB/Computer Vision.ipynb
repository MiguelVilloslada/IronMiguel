# %% [markdown]
# # Trial for Facebook facial recognition software

# %% [markdown]
# Claim accusing Facebook of violating the state’s biometric privacy laws.
# Storing biometric data of each user’s face without their knowledge or consent.

# %% [markdown]
# https://zbigatron.com/recent-controversies-in-computer-vision/

# %%
# %matplotlib inline
from IPython.display import Image
Image('Computer Vision_image.png')

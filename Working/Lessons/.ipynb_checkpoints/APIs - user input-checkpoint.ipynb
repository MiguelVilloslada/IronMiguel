# %%
entered_value=input('enter some value:')
# Out:
# enter some value:123

# %%
entered_value
# Out:
# '123'

# %%
name=input('enter your name ').lstrip().lower() # strip from the left
shoe_size=input('enter your shoe size ')
#shoe_size=int(input('enter your shoe size ')) for float
# Out:
# enter your name Miguel
# enter your shoe size 43

# %%
type(shoe_size)
# Out:
# str

# %%
name
# Out:
# 'miguel'

# %% [markdown]
# ## 1.1 exception handling

# %%
try:
    shoe_size=int(input('enter your shoe size in whole numbers: '))
    print('great job, thats a shoe size. the number is ',shoe_size)
          
except ValueError:
          print('this is not a whole number, try again....')
# Out:
# enter your shoe size in whole numbers: migueel
# this is not a whole number, try again....

# %%
if len(input('enter a song... '))<2:
    print('input too short, please try again')
# Out:
# enter a song... Miguel

# %%
if len(input('enter a song... '))<2:
    print('did you forget to enter a song, dumbass?')
# Out:
# enter a song...
# did you forget to enter a song, dumbass?

# %% [markdown]
# # 1.2 in this in a list of values

# %%
guest_list=['sian', 'andy', 'miguel', 'roger']

# %%
yourname=input('tell me your name please ')
# Out:
# tell me your name please cath

# %%
if yourname in guest_list:
    print('welcome you are on the guest list, get a free cocktail ')
else:
    print('your name is not down and you are not coming in')
# Out:
# your name is not down and you are not coming in

# %% [markdown]
# # 2 APIs

# %%
import requests
import json

# %%
google = requests.get('https://developers.google.com')
print('Google:', google.status_code)

NBA = requests.get('https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason')
print('NBA:', NBA.status_code)

rotten_tomato = requests.get('http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json')
print('Rotten Tomatoes:', rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# # 2.1 Github API

# %%
github_response=requests.get('https://api.github.com/users/MiguelVilloslada/events/public')
github_response.status_code
# Out:
# 200

# %%
github_response.json()
# Out:
# [{'id': '21954757516',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480374622,
#    'name': 'MiguelVilloslada/BCNDATA2022',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022'},
#   'payload': {'push_id': 9967795743,
#    'size': 19,
#    'distinct_size': 19,
#    'ref': 'refs/heads/main',
#    'head': '679b379ca682313aa2e4fc4272e0e3b204c53baa',
#    'before': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#    'commits': [{'sha': '715975215999642a75b2dde2475ff10cc12309a9',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'github tips to correct week',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/715975215999642a75b2dde2475ff10cc12309a9'},
#     {'sha': '7163e88f2a2880a7f7410f362b84cdc7237f2356',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': "Merge branch 'main' of https://github.com/student-IH-labs-and-stuff/BCNDATA2022",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/7163e88f2a2880a7f7410f362b84cdc7237f2356'},
#     {'sha': '3b4c565822ba54d4297f8c6171729a57ffa499fc',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create Dictionaries_lists_nested_17May.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/3b4c565822ba54d4297f8c6171729a57ffa499fc'},
#     {'sha': '15a0f51296d29eb70d7f29f6113d3af93bbb3032',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Geocoding_images.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/15a0f51296d29eb70d7f29f6113d3af93bbb3032'},
#     {'sha': '5a2532c795cfb3cce5843080e7d144796de4fb2c',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/5a2532c795cfb3cce5843080e7d144796de4fb2c'},
#     {'sha': 'bce933756940ae0025e0ea1b1c2b12c6909161f3',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/bce933756940ae0025e0ea1b1c2b12c6909161f3'},
#     {'sha': '338af8264b2122dba4309a13d4fbd84715113a6e',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/338af8264b2122dba4309a13d4fbd84715113a6e'},
#     {'sha': '382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/382e12a8dc0e46b1bb34f1eaffd8b9704bbfafbc'},
#     {'sha': '468bcbf7893980775a15cbbef2a10a110f5caf3c',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/468bcbf7893980775a15cbbef2a10a110f5caf3c'},
#     {'sha': '6d9764a31946c0fe0ac40064f63bd614722da046',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/6d9764a31946c0fe0ac40064f63bd614722da046'},
#     {'sha': 'b1d8f6b9828e55ac6680038e41114957db0570f8',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/b1d8f6b9828e55ac6680038e41114957db0570f8'},
#     {'sha': '832f4ea1b01d57fe326d81348ec5368f76168a71',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/832f4ea1b01d57fe326d81348ec5368f76168a71'},
#     {'sha': '46a6a8c9567208e0ca49de7c97246ca954c46c62',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_Interm.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/46a6a8c9567208e0ca49de7c97246ca954c46c62'},
#     {'sha': '12b437ac31598c07e86950f3e222cc0de16bd6a3',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_Interm.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/12b437ac31598c07e86950f3e222cc0de16bd6a3'},
#     {'sha': 'ba26d1043b77bfd35ad3ed0bb21add261ecbb0b0',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'push week 6 end and first web scrape notebook',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/ba26d1043b77bfd35ad3ed0bb21add261ecbb0b0'},
#     {'sha': '4d8d746deaff9ee62ac63f1753b259d64ae73a72',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': "Merge branch 'main' of https://github.com/student-IH-labs-and-stuff/BCNDATA2022",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/4d8d746deaff9ee62ac63f1753b259d64ae73a72'},
#     {'sha': 'c20b305988c7c42e0d12a97cec4b2cc01c79d1dd',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Update webscrape_one_page.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/c20b305988c7c42e0d12a97cec4b2cc01c79d1dd'},
#     {'sha': '1270664c79d70fb78070bb79fb0a12c51bde3446',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Update webscrape_one_page.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/1270664c79d70fb78070bb79fb0a12c51bde3446'},
#     {'sha': '679b379ca682313aa2e4fc4272e0e3b204c53baa',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create Multiple_page_scraping.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/679b379ca682313aa2e4fc4272e0e3b204c53baa'}]},
#   'public': True,
#   'created_at': '2022-05-24T11:03:50Z'},
#  {'id': '21953556740',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9967208026,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c625bc041c11881e8e598f704cdd6c167febf163',
#    'before': '9d386dc22c16a233bf03d488e42f89e6266eea00',
#    'commits': [{'sha': 'c625bc041c11881e8e598f704cdd6c167febf163',
#      'author': {'email': 'mvillosladarodriguez@gmail.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'LAB Web Scraping',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/c625bc041c11881e8e598f704cdd6c167febf163'}]},
#   'public': True,
#   'created_at': '2022-05-24T10:00:05Z'},
#  {'id': '21953466736',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9967164176,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9d386dc22c16a233bf03d488e42f89e6266eea00',
#    'before': '0934484197334f2ea4ba60755161adcab272e208',
#    'commits': [{'sha': '9d386dc22c16a233bf03d488e42f89e6266eea00',
#      'author': {'email': 'mvillosladarodriguez@gmail.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Web Scraping',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/9d386dc22c16a233bf03d488e42f89e6266eea00'}]},
#   'public': True,
#   'created_at': '2022-05-24T09:55:39Z'},
#  {'id': '21930631677',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9955955723,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0934484197334f2ea4ba60755161adcab272e208',
#    'before': '35cfe5258ec5dc6a8364272bfbba086e3fc68058',
#    'commits': [{'sha': '0934484197334f2ea4ba60755161adcab272e208',
#      'author': {'email': 'mvillosladarodriguez@gmail.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Comparing regression models',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/0934484197334f2ea4ba60755161adcab272e208'}]},
#   'public': True,
#   'created_at': '2022-05-23T09:25:04Z'},
#  {'id': '21897801356',
#   'type': 'ForkEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380100,
#    'name': 'andy1coupe/IronAndy',
#    'url': 'https://api.github.com/repos/andy1coupe/IronAndy'},
#   'payload': {'forkee': {'id': 494418111,
#     'node_id': 'R_kgDOHXg4vw',
#     'name': 'IronAndy',
#     'full_name': 'MiguelVilloslada/IronAndy',
#     'private': False,
#     'owner': {'login': 'MiguelVilloslada',
#      'id': 103429801,
#      'node_id': 'U_kgDOBio2qQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MiguelVilloslada',
#      'html_url': 'https://github.com/MiguelVilloslada',
#      'followers_url': 'https://api.github.com/users/MiguelVilloslada/followers',
#      'following_url': 'https://api.github.com/users/MiguelVilloslada/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MiguelVilloslada/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MiguelVilloslada/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MiguelVilloslada/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MiguelVilloslada/orgs',
#      'repos_url': 'https://api.github.com/users/MiguelVilloslada/repos',
#      'events_url': 'https://api.github.com/users/MiguelVilloslada/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MiguelVilloslada/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/MiguelVilloslada/IronAndy',
#     'description': 'Practice working collaboratively',
#     'fork': True,
#     'url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy',
#     'forks_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/forks',
#     'keys_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/teams',
#     'hooks_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/hooks',
#     'issue_events_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/events',
#     'assignees_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/tags',
#     'blobs_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/languages',
#     'stargazers_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/stargazers',
#     'contributors_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/contributors',
#     'subscribers_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/subscribers',
#     'subscription_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/subscription',
#     'commits_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/merges',
#     'archive_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/downloads',
#     'issues_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/MiguelVilloslada/IronAndy/deployments',
#     'created_at': '2022-05-20T10:20:15Z',
#     'updated_at': '2022-04-12T09:03:21Z',
#     'pushed_at': '2022-05-18T18:13:56Z',
#     'git_url': 'git://github.com/MiguelVilloslada/IronAndy.git',
#     'ssh_url': 'git@github.com:MiguelVilloslada/IronAndy.git',
#     'clone_url': 'https://github.com/MiguelVilloslada/IronAndy.git',
#     'svn_url': 'https://github.com/MiguelVilloslada/IronAndy',
#     'homepage': None,
#     'size': 88436,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-05-20T10:20:15Z'},
#  {'id': '21835186624',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9906660549,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '35cfe5258ec5dc6a8364272bfbba086e3fc68058',
#    'before': 'd84b9006ee64e2de83c26a06cd061d2b1e8b76c6',
#    'commits': [{'sha': '35cfe5258ec5dc6a8364272bfbba086e3fc68058',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update AB Test LAB.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/35cfe5258ec5dc6a8364272bfbba086e3fc68058'}]},
#   'public': True,
#   'created_at': '2022-05-17T15:19:34Z'},
#  {'id': '21831707901',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9905002164,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd84b9006ee64e2de83c26a06cd061d2b1e8b76c6',
#    'before': '0d1c41c2f3c242e0aa82ba36562dd523a8d872a9',
#    'commits': [{'sha': 'd84b9006ee64e2de83c26a06cd061d2b1e8b76c6',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update and rename AB Test LAB to AB Test LAB.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/d84b9006ee64e2de83c26a06cd061d2b1e8b76c6'}]},
#   'public': True,
#   'created_at': '2022-05-17T12:50:58Z'},
#  {'id': '21831626016',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9904961193,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0d1c41c2f3c242e0aa82ba36562dd523a8d872a9',
#    'before': '5319fc8e924de3b78c0a9c653eb29b6f3841c212',
#    'commits': [{'sha': '0d1c41c2f3c242e0aa82ba36562dd523a8d872a9',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update AB Test LAB',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/0d1c41c2f3c242e0aa82ba36562dd523a8d872a9'}]},
#   'public': True,
#   'created_at': '2022-05-17T12:47:08Z'},
#  {'id': '21831480977',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9904889494,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5319fc8e924de3b78c0a9c653eb29b6f3841c212',
#    'before': 'f3fa81adf3da970d47a8952695603640bbe8abcb',
#    'commits': [{'sha': '5319fc8e924de3b78c0a9c653eb29b6f3841c212',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update AB Test LAB',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/5319fc8e924de3b78c0a9c653eb29b6f3841c212'}]},
#   'public': True,
#   'created_at': '2022-05-17T12:40:11Z'},
#  {'id': '21831411023',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9904855300,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f3fa81adf3da970d47a8952695603640bbe8abcb',
#    'before': 'af4b4d20a96ccc3c2198e00b0d35103142aca4a8',
#    'commits': [{'sha': 'f3fa81adf3da970d47a8952695603640bbe8abcb',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'AB test LAB',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/f3fa81adf3da970d47a8952695603640bbe8abcb'}]},
#   'public': True,
#   'created_at': '2022-05-17T12:36:48Z'},
#  {'id': '21825062873',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480380106,
#    'name': 'MiguelVilloslada/IronMiguel',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel'},
#   'payload': {'push_id': 9901806663,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'af4b4d20a96ccc3c2198e00b0d35103142aca4a8',
#    'before': '951b19b3815d051cad22d2df3d78d2abfd3d8b58',
#    'commits': [{'sha': 'af4b4d20a96ccc3c2198e00b0d35103142aca4a8',
#      'author': {'email': 'mvillosladarodriguez@gmail.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Anova LAB',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/IronMiguel/commits/af4b4d20a96ccc3c2198e00b0d35103142aca4a8'}]},
#   'public': True,
#   'created_at': '2022-05-17T07:10:57Z'},
#  {'id': '21807862549',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480374622,
#    'name': 'MiguelVilloslada/BCNDATA2022',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022'},
#   'payload': {'push_id': 9893461412,
#    'size': 8,
#    'distinct_size': 8,
#    'ref': 'refs/heads/main',
#    'head': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#    'before': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#    'commits': [{'sha': 'ea807f74bbd67bb865856e837b960bc9f5c5236c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create fri_6_may.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/ea807f74bbd67bb865856e837b960bc9f5c5236c'},
#     {'sha': '79bc6bc74ce60383260e639e59c10c1a89aaddd2',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create abTesting.xlsx',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/79bc6bc74ce60383260e639e59c10c1a89aaddd2'},
#     {'sha': 'bfabaab502edb4f67e696edebade1b7e48875d6c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'move around data for week 6 classes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/bfabaab502edb4f67e696edebade1b7e48875d6c'},
#     {'sha': 'd860d12fe393274daae88bbafbfeee404204bec5',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update data sources week 6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/d860d12fe393274daae88bbafbfeee404204bec5'},
#     {'sha': 'fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_intro.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d'},
#     {'sha': '15e27b2ecb73df710a567f34dd3c2ba715600dc8',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update case study',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/15e27b2ecb73df710a567f34dd3c2ba715600dc8'},
#     {'sha': 'af3fb301741793d1d481f1f6a91213c72c678dde',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create stats_16_May_22.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/af3fb301741793d1d481f1f6a91213c72c678dde'},
#     {'sha': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/fd35099aaa6bc1913262e6be3d91a61277d21b94'}]},
#   'public': True,
#   'created_at': '2022-05-16T12:05:41Z'},
#  {'id': '21772561925',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 491579252,
#    'name': 'MiguelVilloslada/RealEstateProject',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject'},
#   'payload': {'push_id': 9873774773,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': '76798b9c765bc5fb8299dc30e6b3f5eaef9bc66a',
#    'before': '1887abd515746fa994ad225dd04cd29e6227d0cc',
#    'commits': [{'sha': '4dc565c8831ca95375eabb9f62b1535d047d55cf',
#      'author': {'email': '103149782+andy1coupe@users.noreply.github.com',
#       'name': 'andy1coupe'},
#      'message': 'pp presentation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/commits/4dc565c8831ca95375eabb9f62b1535d047d55cf'},
#     {'sha': 'd68c5274ae83e8266cc629608bb024221e1e73d3',
#      'author': {'email': '103149782+andy1coupe@users.noreply.github.com',
#       'name': 'andy1coupe'},
#      'message': 'Update .DS_Store',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/commits/d68c5274ae83e8266cc629608bb024221e1e73d3'},
#     {'sha': '76798b9c765bc5fb8299dc30e6b3f5eaef9bc66a',
#      'author': {'email': '103149782+andy1coupe@users.noreply.github.com',
#       'name': 'andy1coupe'},
#      'message': 'updated presentation final',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/commits/76798b9c765bc5fb8299dc30e6b3f5eaef9bc66a'}]},
#   'public': True,
#   'created_at': '2022-05-13T10:31:52Z'},
#  {'id': '21758231718',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 491579252,
#    'name': 'MiguelVilloslada/RealEstateProject',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject'},
#   'payload': {'push_id': 9866510544,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1887abd515746fa994ad225dd04cd29e6227d0cc',
#    'before': '9b1012757d221c4b6efaf36efde303c35e152482',
#    'commits': [{'sha': '1887abd515746fa994ad225dd04cd29e6227d0cc',
#      'author': {'email': '103149782+andy1coupe@users.noreply.github.com',
#       'name': 'andy1coupe'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/commits/1887abd515746fa994ad225dd04cd29e6227d0cc'}]},
#   'public': True,
#   'created_at': '2022-05-12T15:59:23Z'},
#  {'id': '21758166996',
#   'type': 'ForkEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 491540057,
#    'name': 'andy1coupe/RealEstateProject',
#    'url': 'https://api.github.com/repos/andy1coupe/RealEstateProject'},
#   'payload': {'forkee': {'id': 491579252,
#     'node_id': 'R_kgDOHUzndA',
#     'name': 'RealEstateProject',
#     'full_name': 'MiguelVilloslada/RealEstateProject',
#     'private': False,
#     'owner': {'login': 'MiguelVilloslada',
#      'id': 103429801,
#      'node_id': 'U_kgDOBio2qQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MiguelVilloslada',
#      'html_url': 'https://github.com/MiguelVilloslada',
#      'followers_url': 'https://api.github.com/users/MiguelVilloslada/followers',
#      'following_url': 'https://api.github.com/users/MiguelVilloslada/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MiguelVilloslada/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MiguelVilloslada/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MiguelVilloslada/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MiguelVilloslada/orgs',
#      'repos_url': 'https://api.github.com/users/MiguelVilloslada/repos',
#      'events_url': 'https://api.github.com/users/MiguelVilloslada/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MiguelVilloslada/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/MiguelVilloslada/RealEstateProject',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject',
#     'forks_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/forks',
#     'keys_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/teams',
#     'hooks_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/hooks',
#     'issue_events_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/events',
#     'assignees_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/tags',
#     'blobs_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/languages',
#     'stargazers_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/stargazers',
#     'contributors_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/contributors',
#     'subscribers_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/subscribers',
#     'subscription_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/subscription',
#     'commits_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/merges',
#     'archive_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/downloads',
#     'issues_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/MiguelVilloslada/RealEstateProject/deployments',
#     'created_at': '2022-05-12T15:56:06Z',
#     'updated_at': '2022-05-12T14:24:20Z',
#     'pushed_at': '2022-05-12T15:51:13Z',
#     'git_url': 'git://github.com/MiguelVilloslada/RealEstateProject.git',
#     'ssh_url': 'git@github.com:MiguelVilloslada/RealEstateProject.git',
#     'clone_url': 'https://github.com/MiguelVilloslada/RealEstateProject.git',
#     'svn_url': 'https://github.com/MiguelVilloslada/RealEstateProject',
#     'homepage': None,
#     'size': 5885,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-05-12T15:56:07Z'},
#  {'id': '21657727759',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 480374622,
#    'name': 'MiguelVilloslada/BCNDATA2022',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022'},
#   'payload': {'push_id': 9814733629,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/main',
#    'head': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#    'before': 'f2999f00e47e5a2e6184430f017f5bbd75e2fac8',
#    'commits': [{'sha': '03c6c8c74750a1c23890730190a795612f11db07',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Update Imbalanced_data.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/03c6c8c74750a1c23890730190a795612f11db07'},
#     {'sha': '5863921bce905c3f7c3384116c29c22c903c9a7e',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create EDA_lesson.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/5863921bce905c3f7c3384116c29c22c903c9a7e'},
#     {'sha': 'f776695ba6a3dee9795607ef64c8a74ef2245b75',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update EDA notebook',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/f776695ba6a3dee9795607ef64c8a74ef2245b75'},
#     {'sha': '063135cae9ee2b7a2e5ffa20ef43c71d4cef18dd',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'end of day 4 week 4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/063135cae9ee2b7a2e5ffa20ef43c71d4cef18dd'},
#     {'sha': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'removed and re added wine notebook under new name',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/BCNDATA2022/commits/c5e207df710d3b445b48df4757608fc6d04af00c'}]},
#   'public': True,
#   'created_at': '2022-05-06T15:40:47Z'},
#  {'id': '21618259062',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794968487,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1d8c5230d1d73763e4ab27022e7003d6cdca7ae0',
#    'before': '0776532d30fbc28a835272e3c6404bd4068d6121',
#    'commits': [{'sha': '1d8c5230d1d73763e4ab27022e7003d6cdca7ae0',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/1d8c5230d1d73763e4ab27022e7003d6cdca7ae0'}]},
#   'public': True,
#   'created_at': '2022-05-04T16:28:31Z'},
#  {'id': '21618225550',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794952213,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0776532d30fbc28a835272e3c6404bd4068d6121',
#    'before': '1266c1e2c6e180ff42598773f0c6d57d0ed7bef4',
#    'commits': [{'sha': '0776532d30fbc28a835272e3c6404bd4068d6121',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/0776532d30fbc28a835272e3c6404bd4068d6121'}]},
#   'public': True,
#   'created_at': '2022-05-04T16:26:38Z'},
#  {'id': '21617963824',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794825626,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1266c1e2c6e180ff42598773f0c6d57d0ed7bef4',
#    'before': '8c2b1fe853ec48835f0ec541f711b15909cb6430',
#    'commits': [{'sha': '1266c1e2c6e180ff42598773f0c6d57d0ed7bef4',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/1266c1e2c6e180ff42598773f0c6d57d0ed7bef4'}]},
#   'public': True,
#   'created_at': '2022-05-04T16:12:07Z'},
#  {'id': '21617919842',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794804651,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8c2b1fe853ec48835f0ec541f711b15909cb6430',
#    'before': '79575fc1f1bc833d75bd02db50366e0deb02e1bb',
#    'commits': [{'sha': '8c2b1fe853ec48835f0ec541f711b15909cb6430',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/8c2b1fe853ec48835f0ec541f711b15909cb6430'}]},
#   'public': True,
#   'created_at': '2022-05-04T16:09:47Z'},
#  {'id': '21617904847',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794797360,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '79575fc1f1bc833d75bd02db50366e0deb02e1bb',
#    'before': 'ea945faa1f8b634b75fad9b278fa4f506bda3344',
#    'commits': [{'sha': '79575fc1f1bc833d75bd02db50366e0deb02e1bb',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/79575fc1f1bc833d75bd02db50366e0deb02e1bb'}]},
#   'public': True,
#   'created_at': '2022-05-04T16:09:00Z'},
#  {'id': '21617555353',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794629823,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ea945faa1f8b634b75fad9b278fa4f506bda3344',
#    'before': '36c47a3e47cdfba8ab00f90cf6aa978a7298db9a',
#    'commits': [{'sha': 'ea945faa1f8b634b75fad9b278fa4f506bda3344',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/ea945faa1f8b634b75fad9b278fa4f506bda3344'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:51:09Z'},
#  {'id': '21617531946',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794618563,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '36c47a3e47cdfba8ab00f90cf6aa978a7298db9a',
#    'before': '48ba76556a51325cf730e67ce5a9bbfd016e3a75',
#    'commits': [{'sha': '36c47a3e47cdfba8ab00f90cf6aa978a7298db9a',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/36c47a3e47cdfba8ab00f90cf6aa978a7298db9a'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:49:59Z'},
#  {'id': '21617489750',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794598189,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '48ba76556a51325cf730e67ce5a9bbfd016e3a75',
#    'before': 'cecda982b283a8d1f79d8ed1575c810b49b8b666',
#    'commits': [{'sha': '48ba76556a51325cf730e67ce5a9bbfd016e3a75',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/48ba76556a51325cf730e67ce5a9bbfd016e3a75'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:47:49Z'},
#  {'id': '21617477300',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794592097,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cecda982b283a8d1f79d8ed1575c810b49b8b666',
#    'before': '24ab618bc9d2b90ab87bdb89e10520894777d205',
#    'commits': [{'sha': 'cecda982b283a8d1f79d8ed1575c810b49b8b666',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/cecda982b283a8d1f79d8ed1575c810b49b8b666'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:47:10Z'},
#  {'id': '21617375644',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794543516,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '24ab618bc9d2b90ab87bdb89e10520894777d205',
#    'before': '4c736823d9eaf0cc4a4971ec199ce9526114cadb',
#    'commits': [{'sha': '24ab618bc9d2b90ab87bdb89e10520894777d205',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/24ab618bc9d2b90ab87bdb89e10520894777d205'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:41:56Z'},
#  {'id': '21617268393',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794492650,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4c736823d9eaf0cc4a4971ec199ce9526114cadb',
#    'before': 'fbe1981339d216a9e6780cc818fda9b9e2ca7214',
#    'commits': [{'sha': '4c736823d9eaf0cc4a4971ec199ce9526114cadb',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/4c736823d9eaf0cc4a4971ec199ce9526114cadb'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:36:33Z'},
#  {'id': '21616933713',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794334415,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fbe1981339d216a9e6780cc818fda9b9e2ca7214',
#    'before': '47a24bd6b66ff8173ed9735b15f7a0198d89e5c9',
#    'commits': [{'sha': 'fbe1981339d216a9e6780cc818fda9b9e2ca7214',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/fbe1981339d216a9e6780cc818fda9b9e2ca7214'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:20:33Z'},
#  {'id': '21616848619',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794294535,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '47a24bd6b66ff8173ed9735b15f7a0198d89e5c9',
#    'before': '94913f4fb9fd57024aa5ac036cab9e28b402b84a',
#    'commits': [{'sha': '47a24bd6b66ff8173ed9735b15f7a0198d89e5c9',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/47a24bd6b66ff8173ed9735b15f7a0198d89e5c9'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:16:29Z'},
#  {'id': '21616791136',
#   'type': 'PushEvent',
#   'actor': {'id': 103429801,
#    'login': 'MiguelVilloslada',
#    'display_login': 'MiguelVilloslada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MiguelVilloslada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103429801?'},
#   'repo': {'id': 488631314,
#    'name': 'MiguelVilloslada/Beautiful-readme',
#    'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme'},
#   'payload': {'push_id': 9794266942,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '94913f4fb9fd57024aa5ac036cab9e28b402b84a',
#    'before': 'af64524d666dc7f868183ecaa98133318f850f68',
#    'commits': [{'sha': '94913f4fb9fd57024aa5ac036cab9e28b402b84a',
#      'author': {'email': '103429801+MiguelVilloslada@users.noreply.github.com',
#       'name': 'MiguelVilloslada'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MiguelVilloslada/Beautiful-readme/commits/94913f4fb9fd57024aa5ac036cab9e28b402b84a'}]},
#   'public': True,
#   'created_at': '2022-05-04T15:13:44Z'}]

# %%
import pandas as pd

# %%
pd.DataFrame(github_response.json())
# Out:
#              id       type                                              actor  \
# 0   21954757516  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 1   21953556740  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 2   21953466736  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 3   21930631677  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 4   21897801356  ForkEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 5   21835186624  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 6   21831707901  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 7   21831626016  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 8   21831480977  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 9   21831411023  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 10  21825062873  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 11  21807862549  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 12  21772561925  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 13  21758231718  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 14  21758166996  ForkEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 15  21657727759  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 16  21618259062  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 17  21618225550  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 18  21617963824  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 19  21617919842  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 20  21617904847  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 21  21617555353  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 22  21617531946  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 23  21617489750  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 24  21617477300  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 25  21617375644  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 26  21617268393  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 27  21616933713  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 28  21616848619  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
# 29  21616791136  PushEvent  {'id': 103429801, 'login': 'MiguelVilloslada',...
#
#                                                  repo  \
# 0   {'id': 480374622, 'name': 'MiguelVilloslada/BC...
# 1   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 2   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 3   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 4   {'id': 480380100, 'name': 'andy1coupe/IronAndy...
# 5   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 6   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 7   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 8   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 9   {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 10  {'id': 480380106, 'name': 'MiguelVilloslada/Ir...
# 11  {'id': 480374622, 'name': 'MiguelVilloslada/BC...
# 12  {'id': 491579252, 'name': 'MiguelVilloslada/Re...
# 13  {'id': 491579252, 'name': 'MiguelVilloslada/Re...
# 14  {'id': 491540057, 'name': 'andy1coupe/RealEsta...
# 15  {'id': 480374622, 'name': 'MiguelVilloslada/BC...
# 16  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 17  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 18  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 19  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 20  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 21  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 22  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 23  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 24  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 25  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 26  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 27  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 28  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
# 29  {'id': 488631314, 'name': 'MiguelVilloslada/Be...
#
#                                               payload  public  \
# 0   {'push_id': 9967795743, 'size': 19, 'distinct_...    True
# 1   {'push_id': 9967208026, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 9967164176, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 9955955723, 'size': 1, 'distinct_s...    True
# 4   {'forkee': {'id': 494418111, 'node_id': 'R_kgD...    True
# 5   {'push_id': 9906660549, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 9905002164, 'size': 1, 'distinct_s...    True
# 7   {'push_id': 9904961193, 'size': 1, 'distinct_s...    True
# 8   {'push_id': 9904889494, 'size': 1, 'distinct_s...    True
# 9   {'push_id': 9904855300, 'size': 1, 'distinct_s...    True
# 10  {'push_id': 9901806663, 'size': 1, 'distinct_s...    True
# 11  {'push_id': 9893461412, 'size': 8, 'distinct_s...    True
# 12  {'push_id': 9873774773, 'size': 3, 'distinct_s...    True
# 13  {'push_id': 9866510544, 'size': 1, 'distinct_s...    True
# 14  {'forkee': {'id': 491579252, 'node_id': 'R_kgD...    True
# 15  {'push_id': 9814733629, 'size': 5, 'distinct_s...    True
# 16  {'push_id': 9794968487, 'size': 1, 'distinct_s...    True
# 17  {'push_id': 9794952213, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 9794825626, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 9794804651, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 9794797360, 'size': 1, 'distinct_s...    True
# 21  {'push_id': 9794629823, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 9794618563, 'size': 1, 'distinct_s...    True
# 23  {'push_id': 9794598189, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 9794592097, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 9794543516, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 9794492650, 'size': 1, 'distinct_s...    True
# 27  {'push_id': 9794334415, 'size': 1, 'distinct_s...    True
# 28  {'push_id': 9794294535, 'size': 1, 'distinct_s...    True
# 29  {'push_id': 9794266942, 'size': 1, 'distinct_s...    True
#
#               created_at
# 0   2022-05-24T11:03:50Z
# 1   2022-05-24T10:00:05Z
# 2   2022-05-24T09:55:39Z
# 3   2022-05-23T09:25:04Z
# 4   2022-05-20T10:20:15Z
# 5   2022-05-17T15:19:34Z
# 6   2022-05-17T12:50:58Z
# 7   2022-05-17T12:47:08Z
# 8   2022-05-17T12:40:11Z
# 9   2022-05-17T12:36:48Z
# 10  2022-05-17T07:10:57Z
# 11  2022-05-16T12:05:41Z
# 12  2022-05-13T10:31:52Z
# 13  2022-05-12T15:59:23Z
# 14  2022-05-12T15:56:07Z
# 15  2022-05-06T15:40:47Z
# 16  2022-05-04T16:28:31Z
# 17  2022-05-04T16:26:38Z
# 18  2022-05-04T16:12:07Z
# 19  2022-05-04T16:09:47Z
# 20  2022-05-04T16:09:00Z
# 21  2022-05-04T15:51:09Z
# 22  2022-05-04T15:49:59Z
# 23  2022-05-04T15:47:49Z
# 24  2022-05-04T15:47:10Z
# 25  2022-05-04T15:41:56Z
# 26  2022-05-04T15:36:33Z
# 27  2022-05-04T15:20:33Z
# 28  2022-05-04T15:16:29Z
# 29  2022-05-04T15:13:44Z

# %%
github_df=pd.json_normalize(github_response.json())

# %%
github_df
# Out:
#              id       type  public            created_at   actor.id  \
# 0   21954757516  PushEvent    True  2022-05-24T11:03:50Z  103429801
# 1   21953556740  PushEvent    True  2022-05-24T10:00:05Z  103429801
# 2   21953466736  PushEvent    True  2022-05-24T09:55:39Z  103429801
# 3   21930631677  PushEvent    True  2022-05-23T09:25:04Z  103429801
# 4   21897801356  ForkEvent    True  2022-05-20T10:20:15Z  103429801
# 5   21835186624  PushEvent    True  2022-05-17T15:19:34Z  103429801
# 6   21831707901  PushEvent    True  2022-05-17T12:50:58Z  103429801
# 7   21831626016  PushEvent    True  2022-05-17T12:47:08Z  103429801
# 8   21831480977  PushEvent    True  2022-05-17T12:40:11Z  103429801
# 9   21831411023  PushEvent    True  2022-05-17T12:36:48Z  103429801
# 10  21825062873  PushEvent    True  2022-05-17T07:10:57Z  103429801
# 11  21807862549  PushEvent    True  2022-05-16T12:05:41Z  103429801
# 12  21772561925  PushEvent    True  2022-05-13T10:31:52Z  103429801
# 13  21758231718  PushEvent    True  2022-05-12T15:59:23Z  103429801
# 14  21758166996  ForkEvent    True  2022-05-12T15:56:07Z  103429801
# 15  21657727759  PushEvent    True  2022-05-06T15:40:47Z  103429801
# 16  21618259062  PushEvent    True  2022-05-04T16:28:31Z  103429801
# 17  21618225550  PushEvent    True  2022-05-04T16:26:38Z  103429801
# 18  21617963824  PushEvent    True  2022-05-04T16:12:07Z  103429801
# 19  21617919842  PushEvent    True  2022-05-04T16:09:47Z  103429801
# 20  21617904847  PushEvent    True  2022-05-04T16:09:00Z  103429801
# 21  21617555353  PushEvent    True  2022-05-04T15:51:09Z  103429801
# 22  21617531946  PushEvent    True  2022-05-04T15:49:59Z  103429801
# 23  21617489750  PushEvent    True  2022-05-04T15:47:49Z  103429801
# 24  21617477300  PushEvent    True  2022-05-04T15:47:10Z  103429801
# 25  21617375644  PushEvent    True  2022-05-04T15:41:56Z  103429801
# 26  21617268393  PushEvent    True  2022-05-04T15:36:33Z  103429801
# 27  21616933713  PushEvent    True  2022-05-04T15:20:33Z  103429801
# 28  21616848619  PushEvent    True  2022-05-04T15:16:29Z  103429801
# 29  21616791136  PushEvent    True  2022-05-04T15:13:44Z  103429801
#
#          actor.login actor.display_login actor.gravatar_id  \
# 0   MiguelVilloslada    MiguelVilloslada
# 1   MiguelVilloslada    MiguelVilloslada
# 2   MiguelVilloslada    MiguelVilloslada
# 3   MiguelVilloslada    MiguelVilloslada
# 4   MiguelVilloslada    MiguelVilloslada
# 5   MiguelVilloslada    MiguelVilloslada
# 6   MiguelVilloslada    MiguelVilloslada
# 7   MiguelVilloslada    MiguelVilloslada
# 8   MiguelVilloslada    MiguelVilloslada
# 9   MiguelVilloslada    MiguelVilloslada
# 10  MiguelVilloslada    MiguelVilloslada
# 11  MiguelVilloslada    MiguelVilloslada
# 12  MiguelVilloslada    MiguelVilloslada
# 13  MiguelVilloslada    MiguelVilloslada
# 14  MiguelVilloslada    MiguelVilloslada
# 15  MiguelVilloslada    MiguelVilloslada
# 16  MiguelVilloslada    MiguelVilloslada
# 17  MiguelVilloslada    MiguelVilloslada
# 18  MiguelVilloslada    MiguelVilloslada
# 19  MiguelVilloslada    MiguelVilloslada
# 20  MiguelVilloslada    MiguelVilloslada
# 21  MiguelVilloslada    MiguelVilloslada
# 22  MiguelVilloslada    MiguelVilloslada
# 23  MiguelVilloslada    MiguelVilloslada
# 24  MiguelVilloslada    MiguelVilloslada
# 25  MiguelVilloslada    MiguelVilloslada
# 26  MiguelVilloslada    MiguelVilloslada
# 27  MiguelVilloslada    MiguelVilloslada
# 28  MiguelVilloslada    MiguelVilloslada
# 29  MiguelVilloslada    MiguelVilloslada
#
#                                         actor.url  \
# 0   https://api.github.com/users/MiguelVilloslada
# 1   https://api.github.com/users/MiguelVilloslada
# 2   https://api.github.com/users/MiguelVilloslada
# 3   https://api.github.com/users/MiguelVilloslada
# 4   https://api.github.com/users/MiguelVilloslada
# 5   https://api.github.com/users/MiguelVilloslada
# 6   https://api.github.com/users/MiguelVilloslada
# 7   https://api.github.com/users/MiguelVilloslada
# 8   https://api.github.com/users/MiguelVilloslada
# 9   https://api.github.com/users/MiguelVilloslada
# 10  https://api.github.com/users/MiguelVilloslada
# 11  https://api.github.com/users/MiguelVilloslada
# 12  https://api.github.com/users/MiguelVilloslada
# 13  https://api.github.com/users/MiguelVilloslada
# 14  https://api.github.com/users/MiguelVilloslada
# 15  https://api.github.com/users/MiguelVilloslada
# 16  https://api.github.com/users/MiguelVilloslada
# 17  https://api.github.com/users/MiguelVilloslada
# 18  https://api.github.com/users/MiguelVilloslada
# 19  https://api.github.com/users/MiguelVilloslada
# 20  https://api.github.com/users/MiguelVilloslada
# 21  https://api.github.com/users/MiguelVilloslada
# 22  https://api.github.com/users/MiguelVilloslada
# 23  https://api.github.com/users/MiguelVilloslada
# 24  https://api.github.com/users/MiguelVilloslada
# 25  https://api.github.com/users/MiguelVilloslada
# 26  https://api.github.com/users/MiguelVilloslada
# 27  https://api.github.com/users/MiguelVilloslada
# 28  https://api.github.com/users/MiguelVilloslada
# 29  https://api.github.com/users/MiguelVilloslada
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/103429...  ...
# 1   https://avatars.githubusercontent.com/u/103429...  ...
# 2   https://avatars.githubusercontent.com/u/103429...  ...
# 3   https://avatars.githubusercontent.com/u/103429...  ...
# 4   https://avatars.githubusercontent.com/u/103429...  ...
# 5   https://avatars.githubusercontent.com/u/103429...  ...
# 6   https://avatars.githubusercontent.com/u/103429...  ...
# 7   https://avatars.githubusercontent.com/u/103429...  ...
# 8   https://avatars.githubusercontent.com/u/103429...  ...
# 9   https://avatars.githubusercontent.com/u/103429...  ...
# 10  https://avatars.githubusercontent.com/u/103429...  ...
# 11  https://avatars.githubusercontent.com/u/103429...  ...
# 12  https://avatars.githubusercontent.com/u/103429...  ...
# 13  https://avatars.githubusercontent.com/u/103429...  ...
# 14  https://avatars.githubusercontent.com/u/103429...  ...
# 15  https://avatars.githubusercontent.com/u/103429...  ...
# 16  https://avatars.githubusercontent.com/u/103429...  ...
# 17  https://avatars.githubusercontent.com/u/103429...  ...
# 18  https://avatars.githubusercontent.com/u/103429...  ...
# 19  https://avatars.githubusercontent.com/u/103429...  ...
# 20  https://avatars.githubusercontent.com/u/103429...  ...
# 21  https://avatars.githubusercontent.com/u/103429...  ...
# 22  https://avatars.githubusercontent.com/u/103429...  ...
# 23  https://avatars.githubusercontent.com/u/103429...  ...
# 24  https://avatars.githubusercontent.com/u/103429...  ...
# 25  https://avatars.githubusercontent.com/u/103429...  ...
# 26  https://avatars.githubusercontent.com/u/103429...  ...
# 27  https://avatars.githubusercontent.com/u/103429...  ...
# 28  https://avatars.githubusercontent.com/u/103429...  ...
# 29  https://avatars.githubusercontent.com/u/103429...  ...
#
#     payload.forkee.license payload.forkee.allow_forking  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                         True
# 5                      NaN                          NaN
# 6                      NaN                          NaN
# 7                      NaN                          NaN
# 8                      NaN                          NaN
# 9                      NaN                          NaN
# 10                     NaN                          NaN
# 11                     NaN                          NaN
# 12                     NaN                          NaN
# 13                     NaN                          NaN
# 14                     NaN                         True
# 15                     NaN                          NaN
# 16                     NaN                          NaN
# 17                     NaN                          NaN
# 18                     NaN                          NaN
# 19                     NaN                          NaN
# 20                     NaN                          NaN
# 21                     NaN                          NaN
# 22                     NaN                          NaN
# 23                     NaN                          NaN
# 24                     NaN                          NaN
# 25                     NaN                          NaN
# 26                     NaN                          NaN
# 27                     NaN                          NaN
# 28                     NaN                          NaN
# 29                     NaN                          NaN
#
#    payload.forkee.is_template  payload.forkee.topics  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                       False                     []
# 5                         NaN                    NaN
# 6                         NaN                    NaN
# 7                         NaN                    NaN
# 8                         NaN                    NaN
# 9                         NaN                    NaN
# 10                        NaN                    NaN
# 11                        NaN                    NaN
# 12                        NaN                    NaN
# 13                        NaN                    NaN
# 14                      False                     []
# 15                        NaN                    NaN
# 16                        NaN                    NaN
# 17                        NaN                    NaN
# 18                        NaN                    NaN
# 19                        NaN                    NaN
# 20                        NaN                    NaN
# 21                        NaN                    NaN
# 22                        NaN                    NaN
# 23                        NaN                    NaN
# 24                        NaN                    NaN
# 25                        NaN                    NaN
# 26                        NaN                    NaN
# 27                        NaN                    NaN
# 28                        NaN                    NaN
# 29                        NaN                    NaN
#
#     payload.forkee.visibility  payload.forkee.forks  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                      public                   0.0
# 5                         NaN                   NaN
# 6                         NaN                   NaN
# 7                         NaN                   NaN
# 8                         NaN                   NaN
# 9                         NaN                   NaN
# 10                        NaN                   NaN
# 11                        NaN                   NaN
# 12                        NaN                   NaN
# 13                        NaN                   NaN
# 14                     public                   0.0
# 15                        NaN                   NaN
# 16                        NaN                   NaN
# 17                        NaN                   NaN
# 18                        NaN                   NaN
# 19                        NaN                   NaN
# 20                        NaN                   NaN
# 21                        NaN                   NaN
# 22                        NaN                   NaN
# 23                        NaN                   NaN
# 24                        NaN                   NaN
# 25                        NaN                   NaN
# 26                        NaN                   NaN
# 27                        NaN                   NaN
# 28                        NaN                   NaN
# 29                        NaN                   NaN
#
#    payload.forkee.open_issues payload.forkee.watchers  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         0.0                     0.0
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# 7                         NaN                     NaN
# 8                         NaN                     NaN
# 9                         NaN                     NaN
# 10                        NaN                     NaN
# 11                        NaN                     NaN
# 12                        NaN                     NaN
# 13                        NaN                     NaN
# 14                        0.0                     0.0
# 15                        NaN                     NaN
# 16                        NaN                     NaN
# 17                        NaN                     NaN
# 18                        NaN                     NaN
# 19                        NaN                     NaN
# 20                        NaN                     NaN
# 21                        NaN                     NaN
# 22                        NaN                     NaN
# 23                        NaN                     NaN
# 24                        NaN                     NaN
# 25                        NaN                     NaN
# 26                        NaN                     NaN
# 27                        NaN                     NaN
# 28                        NaN                     NaN
# 29                        NaN                     NaN
#
#    payload.forkee.default_branch payload.forkee.public
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                           main                  True
# 5                            NaN                   NaN
# 6                            NaN                   NaN
# 7                            NaN                   NaN
# 8                            NaN                   NaN
# 9                            NaN                   NaN
# 10                           NaN                   NaN
# 11                           NaN                   NaN
# 12                           NaN                   NaN
# 13                           NaN                   NaN
# 14                          main                  True
# 15                           NaN                   NaN
# 16                           NaN                   NaN
# 17                           NaN                   NaN
# 18                           NaN                   NaN
# 19                           NaN                   NaN
# 20                           NaN                   NaN
# 21                           NaN                   NaN
# 22                           NaN                   NaN
# 23                           NaN                   NaN
# 24                           NaN                   NaN
# 25                           NaN                   NaN
# 26                           NaN                   NaN
# 27                           NaN                   NaN
# 28                           NaN                   NaN
# 29                           NaN                   NaN
#
# [30 rows x 115 columns]

# %%
github_df.iloc[:,1:25]
# Out:
#          type  public            created_at   actor.id       actor.login  \
# 0   PushEvent    True  2022-05-24T11:03:50Z  103429801  MiguelVilloslada
# 1   PushEvent    True  2022-05-24T10:00:05Z  103429801  MiguelVilloslada
# 2   PushEvent    True  2022-05-24T09:55:39Z  103429801  MiguelVilloslada
# 3   PushEvent    True  2022-05-23T09:25:04Z  103429801  MiguelVilloslada
# 4   ForkEvent    True  2022-05-20T10:20:15Z  103429801  MiguelVilloslada
# 5   PushEvent    True  2022-05-17T15:19:34Z  103429801  MiguelVilloslada
# 6   PushEvent    True  2022-05-17T12:50:58Z  103429801  MiguelVilloslada
# 7   PushEvent    True  2022-05-17T12:47:08Z  103429801  MiguelVilloslada
# 8   PushEvent    True  2022-05-17T12:40:11Z  103429801  MiguelVilloslada
# 9   PushEvent    True  2022-05-17T12:36:48Z  103429801  MiguelVilloslada
# 10  PushEvent    True  2022-05-17T07:10:57Z  103429801  MiguelVilloslada
# 11  PushEvent    True  2022-05-16T12:05:41Z  103429801  MiguelVilloslada
# 12  PushEvent    True  2022-05-13T10:31:52Z  103429801  MiguelVilloslada
# 13  PushEvent    True  2022-05-12T15:59:23Z  103429801  MiguelVilloslada
# 14  ForkEvent    True  2022-05-12T15:56:07Z  103429801  MiguelVilloslada
# 15  PushEvent    True  2022-05-06T15:40:47Z  103429801  MiguelVilloslada
# 16  PushEvent    True  2022-05-04T16:28:31Z  103429801  MiguelVilloslada
# 17  PushEvent    True  2022-05-04T16:26:38Z  103429801  MiguelVilloslada
# 18  PushEvent    True  2022-05-04T16:12:07Z  103429801  MiguelVilloslada
# 19  PushEvent    True  2022-05-04T16:09:47Z  103429801  MiguelVilloslada
# 20  PushEvent    True  2022-05-04T16:09:00Z  103429801  MiguelVilloslada
# 21  PushEvent    True  2022-05-04T15:51:09Z  103429801  MiguelVilloslada
# 22  PushEvent    True  2022-05-04T15:49:59Z  103429801  MiguelVilloslada
# 23  PushEvent    True  2022-05-04T15:47:49Z  103429801  MiguelVilloslada
# 24  PushEvent    True  2022-05-04T15:47:10Z  103429801  MiguelVilloslada
# 25  PushEvent    True  2022-05-04T15:41:56Z  103429801  MiguelVilloslada
# 26  PushEvent    True  2022-05-04T15:36:33Z  103429801  MiguelVilloslada
# 27  PushEvent    True  2022-05-04T15:20:33Z  103429801  MiguelVilloslada
# 28  PushEvent    True  2022-05-04T15:16:29Z  103429801  MiguelVilloslada
# 29  PushEvent    True  2022-05-04T15:13:44Z  103429801  MiguelVilloslada
#
#    actor.display_login actor.gravatar_id  \
# 0     MiguelVilloslada
# 1     MiguelVilloslada
# 2     MiguelVilloslada
# 3     MiguelVilloslada
# 4     MiguelVilloslada
# 5     MiguelVilloslada
# 6     MiguelVilloslada
# 7     MiguelVilloslada
# 8     MiguelVilloslada
# 9     MiguelVilloslada
# 10    MiguelVilloslada
# 11    MiguelVilloslada
# 12    MiguelVilloslada
# 13    MiguelVilloslada
# 14    MiguelVilloslada
# 15    MiguelVilloslada
# 16    MiguelVilloslada
# 17    MiguelVilloslada
# 18    MiguelVilloslada
# 19    MiguelVilloslada
# 20    MiguelVilloslada
# 21    MiguelVilloslada
# 22    MiguelVilloslada
# 23    MiguelVilloslada
# 24    MiguelVilloslada
# 25    MiguelVilloslada
# 26    MiguelVilloslada
# 27    MiguelVilloslada
# 28    MiguelVilloslada
# 29    MiguelVilloslada
#
#                                         actor.url  \
# 0   https://api.github.com/users/MiguelVilloslada
# 1   https://api.github.com/users/MiguelVilloslada
# 2   https://api.github.com/users/MiguelVilloslada
# 3   https://api.github.com/users/MiguelVilloslada
# 4   https://api.github.com/users/MiguelVilloslada
# 5   https://api.github.com/users/MiguelVilloslada
# 6   https://api.github.com/users/MiguelVilloslada
# 7   https://api.github.com/users/MiguelVilloslada
# 8   https://api.github.com/users/MiguelVilloslada
# 9   https://api.github.com/users/MiguelVilloslada
# 10  https://api.github.com/users/MiguelVilloslada
# 11  https://api.github.com/users/MiguelVilloslada
# 12  https://api.github.com/users/MiguelVilloslada
# 13  https://api.github.com/users/MiguelVilloslada
# 14  https://api.github.com/users/MiguelVilloslada
# 15  https://api.github.com/users/MiguelVilloslada
# 16  https://api.github.com/users/MiguelVilloslada
# 17  https://api.github.com/users/MiguelVilloslada
# 18  https://api.github.com/users/MiguelVilloslada
# 19  https://api.github.com/users/MiguelVilloslada
# 20  https://api.github.com/users/MiguelVilloslada
# 21  https://api.github.com/users/MiguelVilloslada
# 22  https://api.github.com/users/MiguelVilloslada
# 23  https://api.github.com/users/MiguelVilloslada
# 24  https://api.github.com/users/MiguelVilloslada
# 25  https://api.github.com/users/MiguelVilloslada
# 26  https://api.github.com/users/MiguelVilloslada
# 27  https://api.github.com/users/MiguelVilloslada
# 28  https://api.github.com/users/MiguelVilloslada
# 29  https://api.github.com/users/MiguelVilloslada
#
#                                      actor.avatar_url    repo.id  ...  \
# 0   https://avatars.githubusercontent.com/u/103429...  480374622  ...
# 1   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 2   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 3   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 4   https://avatars.githubusercontent.com/u/103429...  480380100  ...
# 5   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 6   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 7   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 8   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 9   https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 10  https://avatars.githubusercontent.com/u/103429...  480380106  ...
# 11  https://avatars.githubusercontent.com/u/103429...  480374622  ...
# 12  https://avatars.githubusercontent.com/u/103429...  491579252  ...
# 13  https://avatars.githubusercontent.com/u/103429...  491579252  ...
# 14  https://avatars.githubusercontent.com/u/103429...  491540057  ...
# 15  https://avatars.githubusercontent.com/u/103429...  480374622  ...
# 16  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 17  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 18  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 19  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 20  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 21  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 22  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 23  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 24  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 25  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 26  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 27  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 28  https://avatars.githubusercontent.com/u/103429...  488631314  ...
# 29  https://avatars.githubusercontent.com/u/103429...  488631314  ...
#
#    payload.distinct_size      payload.ref  \
# 0                   19.0  refs/heads/main
# 1                    1.0  refs/heads/main
# 2                    1.0  refs/heads/main
# 3                    1.0  refs/heads/main
# 4                    NaN              NaN
# 5                    1.0  refs/heads/main
# 6                    1.0  refs/heads/main
# 7                    1.0  refs/heads/main
# 8                    1.0  refs/heads/main
# 9                    1.0  refs/heads/main
# 10                   1.0  refs/heads/main
# 11                   8.0  refs/heads/main
# 12                   3.0  refs/heads/main
# 13                   1.0  refs/heads/main
# 14                   NaN              NaN
# 15                   5.0  refs/heads/main
# 16                   1.0  refs/heads/main
# 17                   1.0  refs/heads/main
# 18                   1.0  refs/heads/main
# 19                   1.0  refs/heads/main
# 20                   1.0  refs/heads/main
# 21                   1.0  refs/heads/main
# 22                   1.0  refs/heads/main
# 23                   1.0  refs/heads/main
# 24                   1.0  refs/heads/main
# 25                   1.0  refs/heads/main
# 26                   1.0  refs/heads/main
# 27                   1.0  refs/heads/main
# 28                   1.0  refs/heads/main
# 29                   1.0  refs/heads/main
#
#                                 payload.head  \
# 0   679b379ca682313aa2e4fc4272e0e3b204c53baa
# 1   c625bc041c11881e8e598f704cdd6c167febf163
# 2   9d386dc22c16a233bf03d488e42f89e6266eea00
# 3   0934484197334f2ea4ba60755161adcab272e208
# 4                                        NaN
# 5   35cfe5258ec5dc6a8364272bfbba086e3fc68058
# 6   d84b9006ee64e2de83c26a06cd061d2b1e8b76c6
# 7   0d1c41c2f3c242e0aa82ba36562dd523a8d872a9
# 8   5319fc8e924de3b78c0a9c653eb29b6f3841c212
# 9   f3fa81adf3da970d47a8952695603640bbe8abcb
# 10  af4b4d20a96ccc3c2198e00b0d35103142aca4a8
# 11  fd35099aaa6bc1913262e6be3d91a61277d21b94
# 12  76798b9c765bc5fb8299dc30e6b3f5eaef9bc66a
# 13  1887abd515746fa994ad225dd04cd29e6227d0cc
# 14                                       NaN
# 15  c5e207df710d3b445b48df4757608fc6d04af00c
# 16  1d8c5230d1d73763e4ab27022e7003d6cdca7ae0
# 17  0776532d30fbc28a835272e3c6404bd4068d6121
# 18  1266c1e2c6e180ff42598773f0c6d57d0ed7bef4
# 19  8c2b1fe853ec48835f0ec541f711b15909cb6430
# 20  79575fc1f1bc833d75bd02db50366e0deb02e1bb
# 21  ea945faa1f8b634b75fad9b278fa4f506bda3344
# 22  36c47a3e47cdfba8ab00f90cf6aa978a7298db9a
# 23  48ba76556a51325cf730e67ce5a9bbfd016e3a75
# 24  cecda982b283a8d1f79d8ed1575c810b49b8b666
# 25  24ab618bc9d2b90ab87bdb89e10520894777d205
# 26  4c736823d9eaf0cc4a4971ec199ce9526114cadb
# 27  fbe1981339d216a9e6780cc818fda9b9e2ca7214
# 28  47a24bd6b66ff8173ed9735b15f7a0198d89e5c9
# 29  94913f4fb9fd57024aa5ac036cab9e28b402b84a
#
#                               payload.before  \
# 0   fd35099aaa6bc1913262e6be3d91a61277d21b94
# 1   9d386dc22c16a233bf03d488e42f89e6266eea00
# 2   0934484197334f2ea4ba60755161adcab272e208
# 3   35cfe5258ec5dc6a8364272bfbba086e3fc68058
# 4                                        NaN
# 5   d84b9006ee64e2de83c26a06cd061d2b1e8b76c6
# 6   0d1c41c2f3c242e0aa82ba36562dd523a8d872a9
# 7   5319fc8e924de3b78c0a9c653eb29b6f3841c212
# 8   f3fa81adf3da970d47a8952695603640bbe8abcb
# 9   af4b4d20a96ccc3c2198e00b0d35103142aca4a8
# 10  951b19b3815d051cad22d2df3d78d2abfd3d8b58
# 11  c5e207df710d3b445b48df4757608fc6d04af00c
# 12  1887abd515746fa994ad225dd04cd29e6227d0cc
# 13  9b1012757d221c4b6efaf36efde303c35e152482
# 14                                       NaN
# 15  f2999f00e47e5a2e6184430f017f5bbd75e2fac8
# 16  0776532d30fbc28a835272e3c6404bd4068d6121
# 17  1266c1e2c6e180ff42598773f0c6d57d0ed7bef4
# 18  8c2b1fe853ec48835f0ec541f711b15909cb6430
# 19  79575fc1f1bc833d75bd02db50366e0deb02e1bb
# 20  ea945faa1f8b634b75fad9b278fa4f506bda3344
# 21  36c47a3e47cdfba8ab00f90cf6aa978a7298db9a
# 22  48ba76556a51325cf730e67ce5a9bbfd016e3a75
# 23  cecda982b283a8d1f79d8ed1575c810b49b8b666
# 24  24ab618bc9d2b90ab87bdb89e10520894777d205
# 25  4c736823d9eaf0cc4a4971ec199ce9526114cadb
# 26  fbe1981339d216a9e6780cc818fda9b9e2ca7214
# 27  47a24bd6b66ff8173ed9735b15f7a0198d89e5c9
# 28  94913f4fb9fd57024aa5ac036cab9e28b402b84a
# 29  af64524d666dc7f868183ecaa98133318f850f68
#
#                                       payload.commits payload.forkee.id  \
# 0   [{'sha': '715975215999642a75b2dde2475ff10cc123...               NaN
# 1   [{'sha': 'c625bc041c11881e8e598f704cdd6c167feb...               NaN
# 2   [{'sha': '9d386dc22c16a233bf03d488e42f89e6266e...               NaN
# 3   [{'sha': '0934484197334f2ea4ba60755161adcab272...               NaN
# 4                                                 NaN       494418111.0
# 5   [{'sha': '35cfe5258ec5dc6a8364272bfbba086e3fc6...               NaN
# 6   [{'sha': 'd84b9006ee64e2de83c26a06cd061d2b1e8b...               NaN
# 7   [{'sha': '0d1c41c2f3c242e0aa82ba36562dd523a8d8...               NaN
# 8   [{'sha': '5319fc8e924de3b78c0a9c653eb29b6f3841...               NaN
# 9   [{'sha': 'f3fa81adf3da970d47a8952695603640bbe8...               NaN
# 10  [{'sha': 'af4b4d20a96ccc3c2198e00b0d35103142ac...               NaN
# 11  [{'sha': 'ea807f74bbd67bb865856e837b960bc9f5c5...               NaN
# 12  [{'sha': '4dc565c8831ca95375eabb9f62b1535d047d...               NaN
# 13  [{'sha': '1887abd515746fa994ad225dd04cd29e6227...               NaN
# 14                                                NaN       491579252.0
# 15  [{'sha': '03c6c8c74750a1c23890730190a795612f11...               NaN
# 16  [{'sha': '1d8c5230d1d73763e4ab27022e7003d6cdca...               NaN
# 17  [{'sha': '0776532d30fbc28a835272e3c6404bd4068d...               NaN
# 18  [{'sha': '1266c1e2c6e180ff42598773f0c6d57d0ed7...               NaN
# 19  [{'sha': '8c2b1fe853ec48835f0ec541f711b15909cb...               NaN
# 20  [{'sha': '79575fc1f1bc833d75bd02db50366e0deb02...               NaN
# 21  [{'sha': 'ea945faa1f8b634b75fad9b278fa4f506bda...               NaN
# 22  [{'sha': '36c47a3e47cdfba8ab00f90cf6aa978a7298...               NaN
# 23  [{'sha': '48ba76556a51325cf730e67ce5a9bbfd016e...               NaN
# 24  [{'sha': 'cecda982b283a8d1f79d8ed1575c810b49b8...               NaN
# 25  [{'sha': '24ab618bc9d2b90ab87bdb89e10520894777...               NaN
# 26  [{'sha': '4c736823d9eaf0cc4a4971ec199ce9526114...               NaN
# 27  [{'sha': 'fbe1981339d216a9e6780cc818fda9b9e2ca...               NaN
# 28  [{'sha': '47a24bd6b66ff8173ed9735b15f7a0198d89...               NaN
# 29  [{'sha': '94913f4fb9fd57024aa5ac036cab9e28b402...               NaN
#
#    payload.forkee.node_id payload.forkee.name  \
# 0                     NaN                 NaN
# 1                     NaN                 NaN
# 2                     NaN                 NaN
# 3                     NaN                 NaN
# 4            R_kgDOHXg4vw            IronAndy
# 5                     NaN                 NaN
# 6                     NaN                 NaN
# 7                     NaN                 NaN
# 8                     NaN                 NaN
# 9                     NaN                 NaN
# 10                    NaN                 NaN
# 11                    NaN                 NaN
# 12                    NaN                 NaN
# 13                    NaN                 NaN
# 14           R_kgDOHUzndA   RealEstateProject
# 15                    NaN                 NaN
# 16                    NaN                 NaN
# 17                    NaN                 NaN
# 18                    NaN                 NaN
# 19                    NaN                 NaN
# 20                    NaN                 NaN
# 21                    NaN                 NaN
# 22                    NaN                 NaN
# 23                    NaN                 NaN
# 24                    NaN                 NaN
# 25                    NaN                 NaN
# 26                    NaN                 NaN
# 27                    NaN                 NaN
# 28                    NaN                 NaN
# 29                    NaN                 NaN
#
#               payload.forkee.full_name  payload.forkee.private
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4            MiguelVilloslada/IronAndy                   False
# 5                                  NaN                     NaN
# 6                                  NaN                     NaN
# 7                                  NaN                     NaN
# 8                                  NaN                     NaN
# 9                                  NaN                     NaN
# 10                                 NaN                     NaN
# 11                                 NaN                     NaN
# 12                                 NaN                     NaN
# 13                                 NaN                     NaN
# 14  MiguelVilloslada/RealEstateProject                   False
# 15                                 NaN                     NaN
# 16                                 NaN                     NaN
# 17                                 NaN                     NaN
# 18                                 NaN                     NaN
# 19                                 NaN                     NaN
# 20                                 NaN                     NaN
# 21                                 NaN                     NaN
# 22                                 NaN                     NaN
# 23                                 NaN                     NaN
# 24                                 NaN                     NaN
# 25                                 NaN                     NaN
# 26                                 NaN                     NaN
# 27                                 NaN                     NaN
# 28                                 NaN                     NaN
# 29                                 NaN                     NaN
#
# [30 rows x 24 columns]

# %% [markdown]
# # 3 Random pointless apis

# %%
response=requests.get('https://api.agify.io?name=miguel')

# %%
response.content
# Out:
# b'{"name":"isabel","age":70,"count":56190}'

# %%
response=requests.get('https://api.nationalize.io?name=miguel')

# %%
response.content
# Out:
# b'{"name":"miguel","country":[{"country_id":"PT","probability":0.08250195640679102},{"country_id":"PE","probability":0.06491564233857829},{"country_id":"ES","probability":0.056188761603854574}]}'

# %%
my_json=json.loads(response.content)

# %%
my_json
# Out:
# {'name': 'miguel',
#  'country': [{'country_id': 'PT', 'probability': 0.08250195640679102},
#   {'country_id': 'PE', 'probability': 0.06491564233857829},
#   {'country_id': 'ES', 'probability': 0.056188761603854574}]}

# %%
new=pd.DataFrame(my_json)

# %%
new
# Out:
#      name                                            country
# 0  miguel  {'country_id': 'PT', 'probability': 0.08250195...
# 1  miguel  {'country_id': 'PE', 'probability': 0.06491564...
# 2  miguel  {'country_id': 'ES', 'probability': 0.05618876...

# %%
# what should i do if im bored
response=requests.get('https://www.boredapi.com/api/activity')

# %%
response.content
# Out:
# b'{"activity":"Color","type":"relaxation","participants":1,"price":0.1,"link":"","key":"5322987","accessibility":0}'

# %% [markdown]
# # 4 International space station

# %%
# install folium on your conda env

# %%
response=requests.get('http://api.open-notify.org/iss-now.json')

# %%
response.json()
# Out:
# {'timestamp': 1653400746,
#  'iss_position': {'latitude': '-4.6401', 'longitude': '-2.1183'},
#  'message': 'success'}

# %%
import folium

# %%
latlong=[response.json()['iss_position']['latitude'],response.json()['iss_position']['longitude']]

# %%
mappy=folium.Map(location=latlong,zoom_starts=5)
#mappy

# %%
icon=folium.Icon(color='pink',
                prefix='fa',
                icon='rocket',
                icon_color='black',)

# %%
icon_data={'location':latlong,'tooltip':'ISS','icon':icon}

# %%
iss_marker=folium.Marker(**icon_data)

# %%
iss_marker.add_to(mappy);

# %%
mappy
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ab7a4b3a0f535b4cd001538156eeee4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ab7a4b3a0f535b4cd001538156eeee4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8ab7a4b3a0f535b4cd001538156eeee4 = L.map(
#                 &quot;map_8ab7a4b3a0f535b4cd001538156eeee4&quot;,
#                 {
#                     center: [-4.6401, -2.1183],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomStarts: 5,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a165e430ad6115c54c2103295830658 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ab7a4b3a0f535b4cd001538156eeee4);
#
#
#             var marker_84d8729d8415ad57ac02ee6a25a1beaf = L.marker(
#                 [-4.6401, -2.1183],
#                 {}
#             ).addTo(map_8ab7a4b3a0f535b4cd001538156eeee4);
#
#
#             var icon_4ac031f5f12e8266e4a0fff561e62c50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_84d8729d8415ad57ac02ee6a25a1beaf.setIcon(icon_4ac031f5f12e8266e4a0fff561e62c50);
#
#
#             marker_84d8729d8415ad57ac02ee6a25a1beaf.bindTooltip(
#                 `&lt;div&gt;
#                      ISS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coordinates={'lat':52.06132, 'lon':-0.47708, 'n':10}
response=requests.get('http://api.open-notify.org/iss-pass.json',params=coordinates)

# %%
from datetime import datetime
datetime.fromtimestamp(1653507790)
# Out:
# datetime.datetime(2022, 5, 25, 21, 43, 10)

# %% [markdown]
# # 5 passing a authorisation key to the api
